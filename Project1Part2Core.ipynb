# %% [markdown]
# <a href="https://colab.research.google.com/github/JDevine1981/Prediction-of-Product-Sales/blob/main/Project1Part2Core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LOADING DATA

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Data/sales_predictions_2023.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df2 = df.copy()

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# How many rows/columns?

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# Review Data Types

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# All columns appear to be assigned the appropriate data type. Further inspection will determine if any columns
# will need to be converted.

# %% [markdown]
# # Duplicated Data

# %% [markdown]
# Checking for Duplicated Data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicated values.

# %% [markdown]
# # Unique Values

# %%
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %% [markdown]
# The column Item_Fat_Content contains five unqiue values, but according to our data dictionary,
# it should only contain two: Low-Fat and Regular.

# %%
# Reviewing value_counts for Item_Fat_Content
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
# Replacing and standardizing inconsistent values
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'low fat':'Low Fat','reg':'Regular','LF': 'Low Fat'})
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# Since the goal of the project is to predict sales for food items, the Item_Identifier, or Product ID, should be set at the index.

# %%
df = df.set_index('Item_Identifier')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-535b0bb67874> in <cell line: 1>()
# ----> 1 df = df.set_index('Item_Identifier')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['Item_Identifier'] are in the columns"

# %%
# Confirm Index is set to Item_Identifier
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# FDA15                                 1999      Medium               Tier 1
# DRC01                                 2009      Medium               Tier 3
# FDN15                                 1999      Medium               Tier 1
# FDX07                                 1998         NaN               Tier 3
# NCD19                                 1987        High               Tier 3
#
#                        Outlet_Type  Item_Outlet_Sales
# Item_Identifier
# FDA15            Supermarket Type1          3735.1380
# DRC01            Supermarket Type2           443.4228
# FDN15            Supermarket Type1          2097.2700
# FDX07                Grocery Store           732.3800
# NCD19            Supermarket Type1           994.7052

# %% [markdown]
# Checking for missing values

# %%
df.isna().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# Identify % of missing data

# %%
df.isna().sum() / len(df) * 100
# Out:
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %% [markdown]
# ## Missing Values:
#
#   There are 1,463 missing values for Item_Weight (17%).
#
#   There are 2,410 missing values for Outlet_size (28%).
#
#   This presents an opportunity to review the object columns and decide whether we can fill in the missing data as MISSING, impute with a value, or drop the column altogether.

# %%
# Create a filter to use in a for loop to loop through the object type columns
data_types = df.dtypes
str_cols = data_types[data_types=='object'].index
str_cols
# Out:
# Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size',
#        'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
# Run for the loop
for col in str_cols:
  print(f'-{col}:')
  print(df[col].value_counts(dropna=False))
  print('\n\n')
# Out:
# -Item_Fat_Content:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64
#
#
#
# -Item_Type:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
#
# -Outlet_Identifier:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64
#
#
#
# -Outlet_Size:
# Medium    2793
# NaN       2410
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
#
#
# -Outlet_Location_Type:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
#
#
# -Outlet_Type:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# Since we are provided with both the location type and outlet type, and neither column contains missing values, it is safe to assume outlet size is a superfluous column that can be dropped.

# %%
# Drop the outlet_size column from the dataframe
df = df.drop(columns=['Outlet_Size'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-3a1f1e3cf310> in <cell line: 2>()
#       1 # Drop the outlet_size column from the dataframe
# ----> 2 df = df.drop(columns=['Outlet_Size'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['Outlet_Size'] not found in axis"

# %%
# Review changes
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Location_Type  \
# Item_Identifier
# FDA15                                 1999               Tier 1
# DRC01                                 2009               Tier 3
# FDN15                                 1999               Tier 1
# FDX07                                 1998               Tier 3
# NCD19                                 1987               Tier 3
#
#                        Outlet_Type  Item_Outlet_Sales
# Item_Identifier
# FDA15            Supermarket Type1          3735.1380
# DRC01            Supermarket Type2           443.4228
# FDN15            Supermarket Type1          2097.2700
# FDX07                Grocery Store           732.3800
# NCD19            Supermarket Type1           994.7052

# %% [markdown]
# We can also rename several columns by removing the terms item and outlet, as it is implied the data refers to the products and locations.

# %%
# Create a rename dictionary
rename_dict = {'Item_Weight':'Weight', 'Item_Fat_Content': 'Fat_Content', 'Item_Visibility': 'Visibility',
'Item_Type': 'Type', 'Item_MRP': 'MRP', 'Outlet_Establishment_Year': 'Establishment_Year', 'Outlet_Location_Type':
'Location_Type'}
rename_dict
# Out:
# {'Item_Weight': 'Weight',
#  'Item_Fat_Content': 'Fat_Content',
#  'Item_Visibility': 'Visibility',
#  'Item_Type': 'Type',
#  'Item_MRP': 'MRP',
#  'Outlet_Establishment_Year': 'Establishment_Year',
#  'Outlet_Location_Type': 'Location_Type'}

# %%
# Dictionary substitution using rename method
df = df.rename(rename_dict, axis=1)
df.head()
# Out:
#                  Weight Fat_Content  Visibility                   Type  \
# Item_Identifier
# FDA15              9.30     Low Fat    0.016047                  Dairy
# DRC01              5.92     Regular    0.019278            Soft Drinks
# FDN15             17.50     Low Fat    0.016760                   Meat
# FDX07             19.20     Regular    0.000000  Fruits and Vegetables
# NCD19              8.93     Low Fat    0.000000              Household
#
#                       MRP Outlet_Identifier  Establishment_Year Location_Type  \
# Item_Identifier
# FDA15            249.8092            OUT049                1999        Tier 1
# DRC01             48.2692            OUT018                2009        Tier 3
# FDN15            141.6180            OUT049                1999        Tier 1
# FDX07            182.0950            OUT010                1998        Tier 3
# NCD19             53.8614            OUT013                1987        Tier 3
#
#                        Outlet_Type  Item_Outlet_Sales
# Item_Identifier
# FDA15            Supermarket Type1          3735.1380
# DRC01            Supermarket Type2           443.4228
# FDN15            Supermarket Type1          2097.2700
# FDX07                Grocery Store           732.3800
# NCD19            Supermarket Type1           994.7052

# %% [markdown]
# For the item weight, we will fill in the missing values with the placeholder '-1'. Further inspection of the data may reveal the item weight is already listed in a duplicate row. There are only 1559 unique values for product ID in 8,523 rows, so it is likley the missing item weights are listed in one or more of the duplicate rows.

# %%
df['Weight'] = df['Weight'].fillna(-1)
df['Weight'].isna().sum()
# Out:
# 0

# %%
# Checking describe after filling null values
df['Weight'].describe()
# Out:
# count    8523.000000
# mean       10.478936
# std         6.720742
# min        -1.000000
# 25%         6.650000
# 50%        11.000000
# 75%        16.000000
# max        21.350000
# Name: Weight, dtype: float64

# %%
# Confirm no additional missing values
df.isna().sum()
# Out:
# Weight                       0
# Fat_Content                  0
# Visibility                   0
# Type                         0
# MRP                          0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# Upon further inspection, the establishment year yields little value in determininig items sales based on product and location. We will drop this column as well.

# %%
# Drop the establishment_year column from the dataframe
df = df.drop(columns=['Establishment_Year'])

# %%
# Review Changes
df.head()
# Out:
#                  Weight Fat_Content  Visibility                   Type  \
# Item_Identifier
# FDA15              9.30     Low Fat    0.016047                  Dairy
# DRC01              5.92     Regular    0.019278            Soft Drinks
# FDN15             17.50     Low Fat    0.016760                   Meat
# FDX07             19.20     Regular    0.000000  Fruits and Vegetables
# NCD19              8.93     Low Fat    0.000000              Household
#
#                       MRP Outlet_Identifier Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15            249.8092            OUT049        Tier 1  Supermarket Type1
# DRC01             48.2692            OUT018        Tier 3  Supermarket Type2
# FDN15            141.6180            OUT049        Tier 1  Supermarket Type1
# FDX07            182.0950            OUT010        Tier 3      Grocery Store
# NCD19             53.8614            OUT013        Tier 3  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# FDA15                    3735.1380
# DRC01                     443.4228
# FDN15                    2097.2700
# FDX07                     732.3800
# NCD19                     994.7052

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8523 entries, FDA15 to DRG01
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Weight             8523 non-null   float64
#  1   Fat_Content        8523 non-null   object
#  2   Visibility         8523 non-null   float64
#  3   Type               8523 non-null   object
#  4   MRP                8523 non-null   float64
#  5   Outlet_Identifier  8523 non-null   object
#  6   Location_Type      8523 non-null   object
#  7   Outlet_Type        8523 non-null   object
#  8   Item_Outlet_Sales  8523 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 923.9+ KB

# %% [markdown]
# SUMMARY STATISTICS FOR NUMERIC VALUES

# %% [markdown]
# The minimum value for visibility is 0, which is not possible. As with the other missing values, we will need to either remove the rows with missing data, fill with a placehodler, or impute a value.

# %%
df.describe().round(2)
# Out:
#         Weight  Visibility      MRP  Item_Outlet_Sales
# count  8523.00     8523.00  8523.00            8523.00
# mean     10.48        0.07   140.99            2181.29
# std       6.72        0.05    62.28            1706.50
# min      -1.00        0.00    31.29              33.29
# 25%       6.65        0.03    93.83             834.25
# 50%      11.00        0.05   143.01            1794.33
# 75%      16.00        0.09   185.64            3101.30
# max      21.35        0.33   266.89           13086.96

# %% [markdown]
# Since 0.00 is not actually a null value, we will first need to convert it to filter all rows with 0.00 visibility and set the value for that filter to null before we can fill in a placeholder.

# %%
# Create a filter to identify the rows where Visibility = 0.00
filter_zero_vis = df['Visibility'] == 0.00

# %%
# Change to a null value
df.loc[filter_zero_vis, 'Visibility']=np.nan

# %%
# Confirm change to null value
df['Visibility'].describe()
# Out:
# count    7997.000000
# mean        0.070482
# std         0.050308
# min         0.003575
# 25%         0.031403
# 50%         0.057792
# 75%         0.098109
# max         0.328391
# Name: Visibility, dtype: float64

# %%
df['Visibility'].isna().sum()
# Out:
# 526

# %%
# Fill the missing values using -1
df['Visibility'] = df['Visibility'].fillna(-1)

# %%
# Confirm changes
df['Visibility'].isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                  Weight Fat_Content  Visibility                   Type  \
# Item_Identifier
# FDA15              9.30     Low Fat    0.016047                  Dairy
# DRC01              5.92     Regular    0.019278            Soft Drinks
# FDN15             17.50     Low Fat    0.016760                   Meat
# FDX07             19.20     Regular   -1.000000  Fruits and Vegetables
# NCD19              8.93     Low Fat   -1.000000              Household
#
#                       MRP Outlet_Identifier Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15            249.8092            OUT049        Tier 1  Supermarket Type1
# DRC01             48.2692            OUT018        Tier 3  Supermarket Type2
# FDN15            141.6180            OUT049        Tier 1  Supermarket Type1
# FDX07            182.0950            OUT010        Tier 3      Grocery Store
# NCD19             53.8614            OUT013        Tier 3  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# FDA15                    3735.1380
# DRC01                     443.4228
# FDN15                    2097.2700
# FDX07                     732.3800
# NCD19                     994.7052

# %%
# Saving the cleaned data to Google Drive
fpath_out = "/content/drive/MyDrive/CodingDojo/01-Fundamentals/Week02/Data/sales-prediction-eda.csv"
df.to_csv(fpath_out, index=True)

# %%
# Loading and inspecting saved file
loaded = pd.read_csv(fpath_out)
loaded.head()
df.head()
# Out:
#                  Weight Fat_Content  Visibility                   Type  \
# Item_Identifier
# FDA15              9.30     Low Fat    0.016047                  Dairy
# DRC01              5.92     Regular    0.019278            Soft Drinks
# FDN15             17.50     Low Fat    0.016760                   Meat
# FDX07             19.20     Regular   -1.000000  Fruits and Vegetables
# NCD19              8.93     Low Fat   -1.000000              Household
#
#                       MRP Outlet_Identifier Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15            249.8092            OUT049        Tier 1  Supermarket Type1
# DRC01             48.2692            OUT018        Tier 3  Supermarket Type2
# FDN15            141.6180            OUT049        Tier 1  Supermarket Type1
# FDX07            182.0950            OUT010        Tier 3      Grocery Store
# NCD19             53.8614            OUT013        Tier 3  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# FDA15                    3735.1380
# DRC01                     443.4228
# FDN15                    2097.2700
# FDX07                     732.3800
# NCD19                     994.7052
